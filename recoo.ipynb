# %% [markdown]
# ***GENERATED CODE FOR recoo PIPELINE.***

# %% [markdown]
# ***DON'T EDIT THIS CODE.***

# %% [markdown]
# ***CONNECTOR FUNCTIONS TO READ DATA.***

# %%
from hdfs3 import HDFileSystem
import datetime
import logging
import warnings
warnings.filterwarnings('ignore')
logging.basicConfig(format='%(levelname)s:%(message)s', level=logging.INFO)


class HDFSConnector:

    def fetch(spark, config):
        ################### INPUT HADOOP HOST PORT TO CONNECT WITH ###############################
        hdfs = HDFileSystem(
            host=eval(config)['host'], port=eval(config)['port'])
        with hdfs.open(eval(config)['url']) as f:
            df = pd.read_csv(f, error_bad_lines=False)
        df = spark.createDataFrame(dfPd)
        display(df.limit(2).toPandas())
        return df

    def put(df, spark, config):
        return df.write.format('csv').options(header='true' if eval(config)["is_header"] == "Use Header Line" else 'false',
                                              delimiter=eval(config)["delimiter"]).save(("%s %s") % (datetime.datetime.now().strftime("%Y-%m-%d %H.%M.%S")+"_", eval(config)['url']))

# %% [markdown]
# ***AUTOML FUNCTIONS***

# %%
import json


class Recommender:

    def run(spark_DF, spark, config):
        stageAttributes = json.loads(config)
        stageAttributes['model']

# %% [markdown]
# ***READING DATAFRAME***

# %%
############## CREATE SPARK SESSION ############################ ENTER YOUR SPARK MASTER IP AND PORT TO CONNECT TO SERVER ################from pyspark.sql import SparkSession
spark = SparkSession.builder.master('spark://0.0.0.0:0000').getOrCreate()
#%run recooHooks.ipynb
try:
	#sourcePreExecutionHook()

	movieratingstrain = HDFSConnector.fetch(spark, "{'url': '/FileStore/platform/uploadedSourceFiles/MovieRatingsTrain.csv', 'filename': 'MovieRatingsTrain.csv', 'delimiter': ',', 'file_type': 'Delimeted', 'dbfs_token': '', 'dbfs_domain': '', 'is_header': 'Use Header Line', 'server_url': '/numtraPlatform/NumtraPlatformV2/uploads/platform/', 'results_url': 'http://localhost:4040/api/read/hdfs'}")

except Exception as ex: 
	logging.error(ex)

# %% [markdown]
# ***TRAIN MODEL***

# %%
#%run recooHooks.ipynb
try:
	#mlPreExecutionHook()

	sarecommender = Recommender.run(movieratingstrain,spark,json.dumps( {"model": "SAR", "autorecommend": 0, "rating": "rating", "user": "userId", "product": "ItemId", "originalfile": "/FileStore/platform/uploadedSourceFiles/MovieRatingsTrain.csv", "timestamp": "Timestamp"}))

	#mlPostExecutionHook(sarecommender)

except Exception as ex: 
	logging.error(ex)
